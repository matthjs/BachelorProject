# %% [markdown]
# # Variational GP (VSGP) with mixed input spaces vs Exact Inference vs Exact Inference with Random Fourier Features

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from gpytorch.mlls.variational_elbo import VariationalELBO
from gpytorch.variational import CholeskyVariationalDistribution
from typing import Tuple
from gp.gp import MixedSingleTaskVariationalGP
import numpy as np
import torch
from gpytorch.mlls.variational_elbo import VariationalELBO
from gpytorch.variational import CholeskyVariationalDistribution, VariationalStrategy

# %%
def generate_dummy_data(num_samples: int = 50):
    """
    Generates dummy data for training the GP model.

    :param num_samples: Number of samples to generate.
    :return: Tuple of input tensor and target tensor.
    """
    continuous_feature = np.random.uniform(0, 1, num_samples).reshape(-1, 1)
    discrete_feature = np.random.randint(0, 3, num_samples).reshape(-1, 1)  # Discrete dimension with values in {0, 1, 2}
    
    inputs = np.hstack([continuous_feature, discrete_feature])
    targets = np.sin(2 * np.pi * continuous_feature).flatten() + 0.1 * discrete_feature.flatten() + 0.1 * np.random.randn(num_samples)
    
    return torch.tensor(inputs, dtype=torch.float64).to(device='cuda'), torch.tensor(targets, dtype=torch.float64).unsqueeze(-1).to(device='cuda')

train_X, train_Y = generate_dummy_data(num_samples=100)
print(train_X[1:5])
print(train_Y[1:5])
# Out:
# tensor([[0.7212, 1.0000],
#         [0.0642, 2.0000],
#         [0.3110, 2.0000],
#         [0.5096, 0.0000]], device='cuda:0', dtype=torch.float64)
# tensor([[-0.9619],
#         [ 0.5505],
#         [ 1.0994],
#         [-0.0298]], device='cuda:0', dtype=torch.float64)

# %%
import gpytorch
from botorch import fit_gpytorch_mll

# Categorical feature index
cat_dims = [1]
# Step 2: Instantiate the Model
model = MixedSingleTaskVariationalGP(
    train_X=train_X,
    train_Y=train_Y,
    cat_dims=cat_dims,
    # num_outputs=1,
    # learn_inducing_points=True,
    # variational_distribution=CholeskyVariationalDistribution(num_inducing_points=32),
    # variational_strategy=VariationalStrategy,
    # inducing_points=32  # Or provide actual inducing points tensor
).to(device='cuda')

# Step 3: Train the Model
# Define the marginal log likelihood
mll = VariationalELBO(model.likelihood, model.model, train_Y.numel())

# Fit the model
# fit_gpytorch_mll(mll)
# Out:
# check torch.Size([])
# /home/matthijs/bsc/BachelorProject/.venv/lib/python3.10/site-packages/botorch/models/utils/assorted.py:202: InputDataWarning: Input data is not standardized (mean = tensor([0.0266], device='cuda:0', dtype=torch.float64), std = tensor([0.6602], device='cuda:0', dtype=torch.float64)). Please consider scaling the input to zero mean and unit variance.
#   warnings.warn(msg, InputDataWarning)

# %%
from tqdm import tqdm

# I do not believe the standard fit_gpytorch_mll function works
num_epochs = 100

model.train()
model.likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for i in range(num_epochs):
    # naive - no batching just epoch over all data
    optimizer.zero_grad()
    output = model(train_X)
    loss = -mll(output, train_Y).mean()
    print("loss -", loss)
    loss.backward()
    optimizer.step()
# Out:
# loss - tensor(1146.9053, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(98.5802, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(58.7755, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(43.9911, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(36.0695, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(31.0560, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(27.5625, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(24.9696, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(22.9574, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(21.3426, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(20.0122, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(18.8924, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(17.9327, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(17.1344, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(16.4085, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(15.7461, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(15.1569, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(14.6233, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(14.1332, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(13.6831, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(13.2651, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(12.8726, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(12.4992, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(12.1421, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(11.7991, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(11.4698, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(11.1500, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(10.8398, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(10.5398, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(10.2491, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(9.9705, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(9.7208, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(9.4693, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(9.2426, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(9.0459, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(8.8414, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(8.6590, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(8.8085, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(8.6612, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(8.5037, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(8.0373, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.8942, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.7496, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.6054, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.4605, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.3153, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.1756, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(7.0363, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.9032, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.7722, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.6448, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.5218, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.4032, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.2888, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.1789, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(6.0743, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.9741, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.8741, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.7757, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.6814, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.5906, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.5030, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.4182, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.3364, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.2581, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.1840, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.1133, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(5.0463, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.9830, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.9230, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.8629, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.8068, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.7535, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.7023, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.6529, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.6053, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.5599, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.5170, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.4765, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.4362, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.3991, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.3641, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.3303, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.2976, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.2663, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.2369, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.2088, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.1818, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.1557, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.1306, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.1067, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.0838, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.0614, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.0400, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(4.0196, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(3.9999, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(3.9806, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(3.9619, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(3.9439, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# loss - tensor(3.9264, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)

# %%
# Step 4: Make Predictions
# Generate test data
"""
test_continuous_feature = np.linspace(0, 1, 100).reshape(-1, 1)
test_categorical_feature = np.zeros_like(test_continuous_feature)  # Use category 0 for visualization
test_X = torch.tensor(np.hstack([test_continuous_feature, test_categorical_feature]), dtype=torch.float64)

# Get the model in evaluation mode
model.eval()
model.likelihood.eval()

# Make predictions
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    predictions = model.likelihood(model(test_X))
    mean = predictions.mean.numpy()
    lower, upper = predictions.confidence_region()
    lower = lower.numpy()
    upper = upper.numpy()
"""

# Step 4: Make Predictions for Each Discrete Category
num_categories = 3
plt.figure(figsize=(15, 5))
for i in range(num_categories):
    # Generate test data for the current category
    test_continuous_feature = np.linspace(0, 1, 100).reshape(-1, 1)
    test_categorical_feature = np.full_like(test_continuous_feature, fill_value=i)  # Use current category
    test_X = torch.tensor(np.hstack([test_continuous_feature, test_categorical_feature]), dtype=torch.float64, device='cuda')

    # Get the model in evaluation mode
    model.eval()
    model.likelihood.eval()

    # Make predictions
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        predictions = model.likelihood(model(test_X))
        mean = predictions.mean.cpu().numpy()
        lower, upper = predictions.confidence_region()
        lower = lower.cpu().numpy()
        upper = upper.cpu().numpy()

    # Plot the results
    plt.subplot(1, num_categories, i+1)
    plt.plot(train_X[train_X[:, 1] == i][:, 0].cpu().numpy(), train_Y[train_X[:, 1] == i].cpu().numpy(), 'k*', label='Training Data')
    plt.plot(test_continuous_feature, mean, 'b', label='Predicted Mean')
    plt.fill_between(test_continuous_feature.flatten(), lower, upper, alpha=0.2, label='Confidence Interval')
    plt.xlabel('Continuous Feature')
    plt.ylabel('Target')
    plt.title(f'Discrete Feature Category {i}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Replication with SingleMixedTaskGP

# %%
from gpytorch import ExactMarginalLogLikelihood
from botorch.models import MixedSingleTaskGP

# Categorical feature index
cat_dims = [1]

# Step 2: Instantiate the Model
model = MixedSingleTaskGP(train_X=train_X, train_Y=train_Y, cat_dims=cat_dims).to(device='cuda')

mll = ExactMarginalLogLikelihood(model.likelihood, model)

fit_gpytorch_mll(mll)
# Out:
# ExactMarginalLogLikelihood(
#   (likelihood): GaussianLikelihood(
#     (noise_covar): HomoskedasticNoise(
#       (noise_prior): GammaPrior()
#       (raw_noise_constraint): GreaterThan(1.000E-06)
#     )
#   )
#   (model): MixedSingleTaskGP(
#     (likelihood): GaussianLikelihood(
#       (noise_covar): HomoskedasticNoise(
#         (noise_prior): GammaPrior()
#         (raw_noise_constraint): GreaterThan(1.000E-06)
#       )
#     )
#     (mean_module): ConstantMean()
#     (covar_module): AdditiveKernel(
#       (kernels): ModuleList(
#         (0): ScaleKernel(
#           (base_kernel): AdditiveKernel(
#             (kernels): ModuleList(
#               (0): MaternKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-04)
#               )
#               (1): ScaleKernel(
#                 (base_kernel): CategoricalKernel(
#                   (raw_lengthscale_constraint): GreaterThan(1.000E-06)
#                 )
#                 (raw_outputscale_constraint): Positive()
#               )
#             )
#           )
#           (raw_outputscale_constraint): Positive()
#         )
#         (1): ScaleKernel(
#           (base_kernel): ProductKernel(
#             (kernels): ModuleList(
#               (0): MaternKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-04)
#               )
#               (1): CategoricalKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-06)
#               )
#             )
#           )
#           (raw_outputscale_constraint): Positive()
#         )
#       )
#     )
#   )
# )

# %%
# Step 4: Make Predictions for Each Discrete Category
num_categories = 3
plt.figure(figsize=(15, 5))
for i in range(num_categories):
    # Generate test data for the current category
    test_continuous_feature = np.linspace(0, 1, 100).reshape(-1, 1)
    test_categorical_feature = np.full_like(test_continuous_feature, fill_value=i)  # Use current category
    test_X = torch.tensor(np.hstack([test_continuous_feature, test_categorical_feature]), dtype=torch.float32).to(device='cuda')

    # Get the model in evaluation mode
    model.eval()
    model.likelihood.eval()

    # Make predictions
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        predictions = model.likelihood(model(test_X))
        mean = predictions.mean.cpu().numpy()
        lower, upper = predictions.confidence_region()
        lower = lower.cpu().numpy()
        upper = upper.cpu().numpy()

    # Plot the results
    plt.subplot(1, num_categories, i+1)
    plt.plot(train_X[train_X[:, 1] == i][:, 0].cpu().numpy(), train_Y[train_X[:, 1] == i].cpu().numpy(), 'k*', label='Training Data')
    plt.plot(test_continuous_feature, mean, 'b', label='Predicted Mean')
    plt.fill_between(test_continuous_feature.flatten(), lower, upper, alpha=0.2, label='Confidence Interval')
    plt.xlabel('Continuous Feature')
    plt.ylabel('Target')
    plt.title(f'Discrete Feature Category {i}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Same but with RFF kernel

# %%
from typing import List
from gpytorch.kernels import RFFKernel


class RFFKernelAdapter:
    """
    Problem with MixedSigleTaskGP is that it strictly allows kernels to only specify
    the batch_shape, ard_num_dims and lengthscale contraint.
    """
    num_samples = 1024

    @staticmethod
    def create_kernel(batch_shape: torch.Size, ard_num_dims: int, active_dims: List[int]) -> RFFKernel:
        return RFFKernel(
            num_samples=RFFKernelAdapter.num_samples,
            batch_shape=batch_shape,
            ard_num_dims=ard_num_dims,
            active_dims=active_dims
        )

# %%
# Categorical feature index
cat_dims = [1]

# Step 2: Instantiate the Model
model = MixedSingleTaskGP(train_X=train_X, train_Y=train_Y, cat_dims=cat_dims,
                          cont_kernel_factory=RFFKernelAdapter.create_kernel).to(device='cuda')

mll = ExactMarginalLogLikelihood(model.likelihood, model)

fit_gpytorch_mll(mll)
# Out:
# /home/matthijs/bsc/BachelorProject/.venv/lib/python3.10/site-packages/botorch/models/utils/assorted.py:202: InputDataWarning: Input data is not standardized (mean = tensor([0.0266], device='cuda:0', dtype=torch.float64), std = tensor([0.6602], device='cuda:0', dtype=torch.float64)). Please consider scaling the input to zero mean and unit variance.
#   warnings.warn(msg, InputDataWarning)
# ExactMarginalLogLikelihood(
#   (likelihood): GaussianLikelihood(
#     (noise_covar): HomoskedasticNoise(
#       (noise_prior): GammaPrior()
#       (raw_noise_constraint): GreaterThan(1.000E-06)
#     )
#   )
#   (model): MixedSingleTaskGP(
#     (likelihood): GaussianLikelihood(
#       (noise_covar): HomoskedasticNoise(
#         (noise_prior): GammaPrior()
#         (raw_noise_constraint): GreaterThan(1.000E-06)
#       )
#     )
#     (mean_module): ConstantMean()
#     (covar_module): AdditiveKernel(
#       (kernels): ModuleList(
#         (0): ScaleKernel(
#           (base_kernel): AdditiveKernel(
#             (kernels): ModuleList(
#               (0): RFFKernel(
#                 (raw_lengthscale_constraint): Positive()
#               )
#               (1): ScaleKernel(
#                 (base_kernel): CategoricalKernel(
#                   (raw_lengthscale_constraint): GreaterThan(1.000E-06)
#                 )
#                 (raw_outputscale_constraint): Positive()
#               )
#             )
#           )
#           (raw_outputscale_constraint): Positive()
#         )
#         (1): ScaleKernel(
#           (base_kernel): ProductKernel(
#             (kernels): ModuleList(
#               (0): RFFKernel(
#                 (raw_lengthscale_constraint): Positive()
#               )
#               (1): CategoricalKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-06)
#               )
#             )
#           )
#           (raw_outputscale_constraint): Positive()
#         )
#       )
#     )
#   )
# )

# %%
# Step 4: Make Predictions for Each Discrete Category
num_categories = 3
plt.figure(figsize=(15, 5))
for i in range(num_categories):
    # Generate test data for the current category
    test_continuous_feature = np.linspace(0, 1, 100).reshape(-1, 1)
    test_categorical_feature = np.full_like(test_continuous_feature, fill_value=i)  # Use current category
    test_X = torch.tensor(np.hstack([test_continuous_feature, test_categorical_feature]), dtype=torch.float32).to(device='cuda')

    # Get the model in evaluation mode
    model.eval()
    model.likelihood.eval()

    # Make predictions
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        predictions = model.likelihood(model(test_X))
        mean = predictions.mean.cpu().numpy()
        lower, upper = predictions.confidence_region()
        lower = lower.cpu().numpy()
        upper = upper.cpu().numpy()

    # Plot the results
    plt.subplot(1, num_categories, i+1)
    plt.plot(train_X[train_X[:, 1] == i][:, 0].cpu().numpy(), train_Y[train_X[:, 1] == i].cpu().numpy(), 'k*', label='Training Data')
    plt.plot(test_continuous_feature, mean, 'b', label='Predicted Mean')
    plt.fill_between(test_continuous_feature.flatten(), lower, upper, alpha=0.2, label='Confidence Interval')
    plt.xlabel('Continuous Feature')
    plt.ylabel('Target')
    plt.title(f'Discrete Feature Category {i}')
    plt.legend()

plt.tight_layout()
plt.show()
